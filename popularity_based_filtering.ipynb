# %% [markdown]
# # Popularity-Based Filtering

# %% [markdown]
# ## Load data

# %%
import pandas as pd

movies_df = pd.read_csv('./data/movies.csv')
credits_df = pd.read_csv('./data/credits.csv')
ratings_df = pd.read_csv('./data/ratings.csv')

# %% [markdown]
# ## Test loaded data

# %%
movies_df.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# ## Calculate a weighted rating

# %% [markdown]
# The IMDB formula `WR = (v / (v+m)) * R + (m / (v+m)) * C` is used for calculating the weighted rating (WR). It calculates the weighted average of two components: the average rating (R) and the average rating of all movies (C), based on the number of votes (v) and a predetermined cutoff (m).
#
# - v: number of votes for a movie
# - m: minimum number of votes required
# - R: average rating of the movie
# - C: average rating across all movies in the dataset

# %%
# Calculate the minimum number of votes required (m) using the 90th percentile of the vote count.
m = movies_df['vote_count'].quantile(0.9)

# display m value
m
# Out:
# 1838.4000000000015

# %% [markdown]
# ### Filter data on threshold
#
# Filtering movies_df based on m ensures that the analysis or recommendations focus on movies with a significant level of engagement,
# typically in the top 10% percentile of the dataset.
# This helps to mitigate the impact of outlier movies with very few votes and ensures that the recommendations are based on
# popular movies with a substantial number of votes.

# %%
# Create a copy of the DataFrame 'movies_df' to avoid modifying the original DataFrame
# Select rows from the copied DataFrame where the 'vote_count' column values are greater than the threshold 'm'
movies_df_filtered = movies_df.copy().loc[movies_df['vote_count'] > m]

# display this df copy
movies_df_filtered.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
# Calculate the mean vote rating (C) across the 'vote_average' column of the filtered DataFrame 'movies_df_filtered'
C = movies_df_filtered['vote_average'].mean()

# display C value
C
# Out:
# 6.962993762993763

# %%
def weighted_rating(row, m=m, C=C):
    """
    Calculate the weighted rating for a movie based on its vote count and average rating.

    Parameters:
    - row: A pandas Series representing a row of the DataFrame containing movie data.
    - m: The minimum number of votes required to be listed in the calculation. Default is provided from the global variable 'm'.
    - C: The mean vote rating across the whole DataFrame. Default is provided from the global variable 'C'.

    Returns:
    - The weighted rating (wr) calculated based on the IMDB formula:
      wr = (v / (v+m)) * R + (m / (v+m)) * C
    """

    # Extract vote count and average rating from the row
    v = row['vote_count']
    R = row['vote_average']

    # Calculate the weighted rating using the provided IMDB formula
    wr = (v / (v+m)) * R + (m / (v+m)) * C

    return wr

# %%
# Create a new column 'weighted_rating' in the DataFrame 'movies_df_filtered'
# Apply the function 'weighted_rating' to each row of the DataFrame, considering the rows stored in the column 'filtered_rows'
# 'axis=1' indicates that the function will be applied row-wise
movies_df_filtered['weighted_rating'] = movies_df_filtered.apply(weighted_rating, axis=1)

# display this df with the added column
movies_df_filtered.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  ... release_date  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   2009-12-10
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   2007-05-19
#
#       revenue  runtime                                   spoken_languages  \
# 0  2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1   961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
#
#      status                                         tagline  \
# 0  Released                     Enter the World of Pandora.
# 1  Released  At the end of the world, the adventure begins.
#
#                                       title vote_average  vote_count  \
# 0                                    Avatar          7.2       11800
# 1  Pirates of the Caribbean: At World's End          6.9        4500
#
#    weighted_rating
# 0         7.168053
# 1         6.918271
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Sort data in a descendent order on 'weighted_rating'

# %%
# Sort the DataFrame 'movies_df_filtered' based on the values in the 'weighted_rating' column in descending order
# The parameter 'ascending=False' specifies that the sorting should be in descending order
sorted_movies_rated = movies_df_filtered.sort_values('weighted_rating', ascending=False)

# Select the top rows (head) of the sorted DataFrame to retrieve the highest-rated movies
sorted_movies_rated.head()
# Out:
#          budget                                             genres  \
# 1881   25000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 662    63000000                      [{"id": 18, "name": "Drama"}]
# 3232    8000000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 3337    6000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 65    185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
#
#                                           homepage   id  \
# 1881                                           NaN  278
# 662     http://www.foxmovies.com/movies/fight-club  550
# 3232                                           NaN  680
# 3337                  http://www.thegodfather.com/  238
# 65    http://thedarkknight.warnerbros.com/dvdsite/  155
#
#                                                keywords original_language  \
# 1881  [{"id": 378, "name": "prison"}, {"id": 417, "n...                en
# 662   [{"id": 825, "name": "support group"}, {"id": ...                en
# 3232  [{"id": 396, "name": "transporter"}, {"id": 14...                en
# 3337  [{"id": 131, "name": "italy"}, {"id": 699, "na...                en
# 65    [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#                 original_title  \
# 1881  The Shawshank Redemption
# 662                 Fight Club
# 3232              Pulp Fiction
# 3337             The Godfather
# 65             The Dark Knight
#
#                                                overview  popularity  \
# 1881  Framed in the 1940s for the double murder of h...  136.747729
# 662   A ticking-time-bomb insomniac and a slippery s...  146.757391
# 3232  A burger-loving hit man, his philosophical par...  121.463076
# 3337  Spanning the years 1945 to 1955, a chronicle o...  143.659698
# 65    Batman raises the stakes in his war on crime. ...  187.322927
#
#                                    production_companies  ... release_date  \
# 1881  [{"name": "Castle Rock Entertainment", "id": 97}]  ...   1994-09-23
# 662   [{"name": "Regency Enterprises", "id": 508}, {...  ...   1999-10-15
# 3232  [{"name": "Miramax Films", "id": 14}, {"name":...  ...   1994-10-08
# 3337  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...   1972-03-14
# 65    [{"name": "DC Comics", "id": 429}, {"name": "L...  ...   2008-07-16
#
#          revenue  runtime                                   spoken_languages  \
# 1881    28341469    142.0           [{"iso_639_1": "en", "name": "English"}]
# 662    100853753    139.0           [{"iso_639_1": "en", "name": "English"}]
# 3232   213928762    154.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 3337   245066411    175.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 65    1004558444    152.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#         status                                            tagline  \
# 1881  Released  Fear can hold you prisoner. Hope can set you f...
# 662   Released                            Mischief. Mayhem. Soap.
# 3232  Released  Just because you are a character doesn't mean ...
# 3337  Released                         An offer you can't refuse.
# 65    Released                                    Why So Serious?
#
#                          title vote_average  vote_count  weighted_rating
# 1881  The Shawshank Redemption          8.5        8205         8.218658
# 662                 Fight Club          8.3        9413         8.081543
# 3232              Pulp Fiction          8.3        8428         8.060583
# 3337             The Godfather          8.4        5893         8.058304
# 65             The Dark Knight          8.2       12002         8.035690
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Clean data

# %%
# Select the 'title' and 'weighted_rating' columns from the sorted DataFrame 'sorted_movies_rated'
cleaned_movies_data = sorted_movies_rated.loc[:, ['title', 'weighted_rating']]

# Select the top rows (head) of the cleaned DataFrame to retrieve the highest-rated movies
cleaned_movies_data.head()
# Out:
#                          title  weighted_rating
# 1881  The Shawshank Redemption         8.218658
# 662                 Fight Club         8.081543
# 3232              Pulp Fiction         8.060583
# 3337             The Godfather         8.058304
# 65             The Dark Knight         8.035690

# %%
# Convert the cleaned DataFrame 'cleaned_movies_data' to a dictionary format
# The parameter 'orient="records"' specifies that each row will be represented as a dictionary
movies_dict = cleaned_movies_data.to_dict(orient='records')

# display this dict or list of dicts (orient='records')
movies_dict
# Out:
# [{'title': 'The Shawshank Redemption', 'weighted_rating': 8.218657798543095},
#  {'title': 'Fight Club', 'weighted_rating': 8.081542539940607},
#  {'title': 'Pulp Fiction', 'weighted_rating': 8.060582846361697},
#  {'title': 'The Godfather', 'weighted_rating': 8.058303506982918},
#  {'title': 'The Dark Knight', 'weighted_rating': 8.035690278741058},
#  {'title': 'Forrest Gump', 'weighted_rating': 7.967125538522511},
#  {'title': 'Inception', 'weighted_rating': 7.965925680796371},
#  {'title': 'Interstellar', 'weighted_rating': 7.935481585301346},
#  {'title': 'The Empire Strikes Back', 'weighted_rating': 7.905326629938545},
#  {'title': "Schindler's List", 'weighted_rating': 7.901460539917588},
#  {'title': 'Whiplash', 'weighted_rating': 7.896554351961089},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'weighted_rating': 7.88891255997412},
#  {'title': 'Spirited Away', 'weighted_rating': 7.86713999258378},
#  {'title': 'Star Wars', 'weighted_rating': 7.852992972902218},
#  {'title': 'The Godfather: Part II', 'weighted_rating': 7.825161837162456},
#  {'title': 'Se7en', 'weighted_rating': 7.825087162833434},
#  {'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'weighted_rating': 7.819182401681406},
#  {'title': 'The Green Mile', 'weighted_rating': 7.813666712063015},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'weighted_rating': 7.795565630845619},
#  {'title': 'Inside Out', 'weighted_rating': 7.773000539851369},
#  {'title': 'The Silence of the Lambs', 'weighted_rating': 7.7672282825306045},
#  {'title': 'Back to the Future', 'weighted_rating': 7.759209808003604},
#  {'title': 'Guardians of the Galaxy', 'weighted_rating': 7.751249329374438},
#  {'title': 'The Imitation Game', 'weighted_rating': 7.747873109991236},
#  {'title': 'Memento', 'weighted_rating': 7.74368739497609},
#  {'title': 'GoodFellas', 'weighted_rating': 7.742100461881389},
#  {'title': 'The Matrix', 'weighted_rating': 7.739690261310676},
#  {'title': 'The Lion King', 'weighted_rating': 7.735746248321098},
#  {'title': 'American History X', 'weighted_rating': 7.731535871351296},
#  {'title': 'The Shining', 'weighted_rating': 7.726430234458258},
#  {'title': "One Flew Over the Cuckoo's Nest",
#   'weighted_rating': 7.721984221189668},
#  {'title': 'The Grand Budapest Hotel', 'weighted_rating': 7.700123908183807},
#  {'title': 'The Wolf of Wall Street', 'weighted_rating': 7.695158719276968},
#  {'title': 'The Prestige', 'weighted_rating': 7.693962136624352},
#  {'title': 'Inglourious Basterds', 'weighted_rating': 7.691665586315096},
#  {'title': 'The Usual Suspects', 'weighted_rating': 7.68953101364538},
#  {'title': 'Gone Girl', 'weighted_rating': 7.676298339552197},
#  {'title': 'Django Unchained', 'weighted_rating': 7.671098206802799},
#  {'title': 'Gladiator', 'weighted_rating': 7.663295645957036},
#  {'title': 'Reservoir Dogs', 'weighted_rating': 7.655592682351363},
#  {'title': 'Psycho', 'weighted_rating': 7.653128062208477},
#  {'title': 'Saving Private Ryan', 'weighted_rating': 7.64985590931223},
#  {'title': 'Room', 'weighted_rating': 7.645138123751519},
#  {'title': 'Dead Poets Society', 'weighted_rating': 7.639932150787457},
#  {'title': 'Return of the Jedi', 'weighted_rating': 7.635124355550594},
#  {'title': 'Alien', 'weighted_rating': 7.626936740518632},
#  {'title': 'The Departed', 'weighted_rating': 7.621146070173168},
#  {'title': '12 Angry Men', 'weighted_rating': 7.619336057064582},
#  {'title': 'Shutter Island', 'weighted_rating': 7.611759607296894},
#  {'title': 'WALL·E', 'weighted_rating': 7.6108339562706195},
#  {'title': 'Her', 'weighted_rating': 7.609776549834507},
#  {'title': 'Big Hero 6', 'weighted_rating': 7.607014289247715},
#  {'title': "Howl's Moving Castle", 'weighted_rating': 7.606143973961386},
#  {'title': 'Princess Mononoke', 'weighted_rating': 7.604900752051011},
#  {'title': 'Scarface', 'weighted_rating': 7.601698089145858},
#  {'title': 'The Good, the Bad and the Ugly',
#   'weighted_rating': 7.596247104132581},
#  {'title': '12 Years a Slave', 'weighted_rating': 7.587505938227947},
#  {'title': 'Eternal Sunshine of the Spotless Mind',
#   'weighted_rating': 7.586253776389285},
#  {'title': 'Blade Runner', 'weighted_rating': 7.577863584898779},
#  {'title': 'American Beauty', 'weighted_rating': 7.565606967792782},
#  {'title': 'Taxi Driver', 'weighted_rating': 7.564084632982973},
#  {'title': 'The Truman Show', 'weighted_rating': 7.558642239528144},
#  {'title': 'Prisoners', 'weighted_rating': 7.55012140672863},
#  {'title': 'Up', 'weighted_rating': 7.5444131796756855},
#  {'title': '2001: A Space Odyssey', 'weighted_rating': 7.543827585370883},
#  {'title': 'Dallas Buyers Club', 'weighted_rating': 7.535383907774054},
#  {'title': 'Good Will Hunting', 'weighted_rating': 7.52950224413639},
#  {'title': 'Harry Potter and the Prisoner of Azkaban',
#   'weighted_rating': 7.524388590855656},
#  {'title': 'Apocalypse Now', 'weighted_rating': 7.510342562769747},
#  {'title': 'Toy Story', 'weighted_rating': 7.509365975446399},
#  {'title': 'The Theory of Everything', 'weighted_rating': 7.5011783380370005},
#  {'title': 'Amélie', 'weighted_rating': 7.501120296380959},
#  {'title': 'Kill Bill: Vol. 1', 'weighted_rating': 7.500378308908822},
#  {'title': 'Requiem for a Dream', 'weighted_rating': 7.49765677906473},
#  {'title': 'Oldboy', 'weighted_rating': 7.496106077572484},
#  {'title': 'The Dark Knight Rises', 'weighted_rating': 7.492998038621371},
#  {'title': 'Gran Torino', 'weighted_rating': 7.487524923622722},
#  {'title': 'The Pianist', 'weighted_rating': 7.4850820370267215},
#  {'title': 'Into the Wild', 'weighted_rating': 7.484901448557917},
#  {'title': 'V for Vendetta', 'weighted_rating': 7.484263380340063},
#  {'title': 'The Big Lebowski', 'weighted_rating': 7.4770312597363215},
#  {'title': 'Terminator 2: Judgment Day', 'weighted_rating': 7.475058560594968},
#  {'title': 'The Martian', 'weighted_rating': 7.471401183111628},
#  {'title': 'Raiders of the Lost Ark', 'weighted_rating': 7.461978731973813},
#  {'title': 'Spotlight', 'weighted_rating': 7.459899154338196},
#  {'title': 'Catch Me If You Can', 'weighted_rating': 7.459485876005207},
#  {'title': 'Trainspotting', 'weighted_rating': 7.457552796075963},
#  {'title': 'Finding Nemo', 'weighted_rating': 7.4528877611536775},
#  {'title': 'Captain America: The Winter Soldier',
#   'weighted_rating': 7.445960188083728},
#  {'title': 'Donnie Darko', 'weighted_rating': 7.443892282981954},
#  {'title': 'Braveheart', 'weighted_rating': 7.438150845293704},
#  {'title': 'Aliens', 'weighted_rating': 7.432146080556645},
#  {'title': 'The Sixth Sense', 'weighted_rating': 7.4282239607429155},
#  {'title': 'Edge of Tomorrow', 'weighted_rating': 7.42511912876885},
#  {'title': 'Jurassic Park', 'weighted_rating': 7.425066881854645},
#  {'title': 'The Notebook', 'weighted_rating': 7.423791685466574},
#  {'title': 'Ex Machina', 'weighted_rating': 7.421900984561811},
#  {'title': 'A Beautiful Mind', 'weighted_rating': 7.420486804036749},
#  {'title': 'No Country for Old Men', 'weighted_rating': 7.420140400274246},
#  {'title': 'The Perks of Being a Wallflower',
#   'weighted_rating': 7.4181024745938196},
#  {'title': 'Toy Story 3', 'weighted_rating': 7.418026499345454},
#  {'title': 'The Hobbit: The Desolation of Smaug',
#   'weighted_rating': 7.415938597681336},
#  {'title': 'Snatch', 'weighted_rating': 7.414779330980072},
#  {'title': 'The Hateful Eight', 'weighted_rating': 7.408410400806186},
#  {'title': 'About Time', 'weighted_rating': 7.40599368410092},
#  {'title': 'Kill Bill: Vol. 2', 'weighted_rating': 7.397616434032859},
#  {'title': 'Titanic', 'weighted_rating': 7.394979759785513},
#  {'title': 'Batman Begins', 'weighted_rating': 7.392661810282007},
#  {'title': 'The Fault in Our Stars', 'weighted_rating': 7.390782815930205},
#  {'title': 'The Help', 'weighted_rating': 7.389490911825774},
#  {'title': 'The Pursuit of Happyness', 'weighted_rating': 7.3894824526487906},
#  {'title': "Harry Potter and the Philosopher's Stone",
#   'weighted_rating': 7.388377700453138},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'weighted_rating': 7.388112035483797},
#  {'title': 'Million Dollar Baby', 'weighted_rating': 7.383239288794065},
#  {'title': 'Nightcrawler', 'weighted_rating': 7.376231079964791},
#  {'title': 'X-Men: Days of Future Past', 'weighted_rating': 7.374563901947517},
#  {'title': 'Monsters, Inc.', 'weighted_rating': 7.37398750815477},
#  {'title': 'Rush', 'weighted_rating': 7.370770212831737},
#  {'title': 'Harry Potter and the Goblet of Fire',
#   'weighted_rating': 7.367421537103531},
#  {'title': 'Indiana Jones and the Last Crusade',
#   'weighted_rating': 7.365334989958266},
#  {'title': 'How to Train Your Dragon 2', 'weighted_rating': 7.363151794735},
#  {'title': "Pan's Labyrinth", 'weighted_rating': 7.3599966663704},
#  {'title': 'Slumdog Millionaire', 'weighted_rating': 7.348987811096097},
#  {'title': "The King's Speech", 'weighted_rating': 7.344886662140061},
#  {'title': 'The Avengers', 'weighted_rating': 7.340989520940162},
#  {'title': 'Ratatouille', 'weighted_rating': 7.340958812689328},
#  {'title': 'Deadpool', 'weighted_rating': 7.337398330441483},
#  {'title': 'How to Train Your Dragon', 'weighted_rating': 7.337235422871984},
#  {'title': 'Me Before You', 'weighted_rating': 7.3338714057557794},
#  {'title': 'Die Hard', 'weighted_rating': 7.329387483389972},
#  {'title': 'Captain Phillips', 'weighted_rating': 7.327175410932748},
#  {'title': 'Iron Man', 'weighted_rating': 7.324311099439227},
#  {'title': 'Edward Scissorhands', 'weighted_rating': 7.318503462493608},
#  {'title': 'Cast Away', 'weighted_rating': 7.304755900223032},
#  {'title': 'The Hunger Games: Catching Fire',
#   'weighted_rating': 7.3035936993169335},
#  {'title': 'The Lego Movie', 'weighted_rating': 7.298868823626382},
#  {'title': 'Mulan', 'weighted_rating': 7.295540696206253},
#  {'title': 'Harry Potter and the Chamber of Secrets',
#   'weighted_rating': 7.2950280573193265},
#  {'title': 'Big Fish', 'weighted_rating': 7.29442848708061},
#  {'title': 'Harry Potter and the Order of the Phoenix',
#   'weighted_rating': 7.290432564220138},
#  {'title': 'Harry Potter and the Half-Blood Prince',
#   'weighted_rating': 7.2873443831348315},
#  {'title': 'The Incredibles', 'weighted_rating': 7.285072060810217},
#  {'title': 'Jaws', 'weighted_rating': 7.274625087637599},
#  {'title': 'Birdman', 'weighted_rating': 7.273946046676457},
#  {'title': 'Star Trek', 'weighted_rating': 7.273608919181886},
#  {'title': 'American Sniper', 'weighted_rating': 7.272627030771433},
#  {'title': 'Star Trek Into Darkness', 'weighted_rating': 7.271588730561942},
#  {'title': 'Shaun of the Dead', 'weighted_rating': 7.268168263640741},
#  {'title': 'Fury', 'weighted_rating': 7.261110527260863},
#  {'title': 'Back to the Future Part II', 'weighted_rating': 7.258243239208055},
#  {'title': 'Drive', 'weighted_rating': 7.255593294368145},
#  {'title': 'Aladdin', 'weighted_rating': 7.247101045578512},
#  {'title': 'Seven Pounds', 'weighted_rating': 7.245388078064614},
#  {'title': 'Tangled', 'weighted_rating': 7.244556871350463},
#  {'title': 'The Exorcist', 'weighted_rating': 7.243135695969125},
#  {'title': 'Boyhood', 'weighted_rating': 7.240843107546525},
#  {'title': 'The Conjuring', 'weighted_rating': 7.237053329118882},
#  {'title': 'Avengers: Age of Ultron', 'weighted_rating': 7.228004245460727},
#  {'title': 'The Revenant', 'weighted_rating': 7.224760484538974},
#  {'title': 'Gravity', 'weighted_rating': 7.218366107187358},
#  {'title': 'Now You See Me', 'weighted_rating': 7.215424104333925},
#  {'title': 'Frozen', 'weighted_rating': 7.213147690286222},
#  {'title': 'Groundhog Day', 'weighted_rating': 7.2059157689249},
#  {'title': 'Black Swan', 'weighted_rating': 7.2011626146844065},
#  {'title': 'Hot Fuzz', 'weighted_rating': 7.201012466906359},
#  {'title': 'Dawn of the Planet of the Apes',
#   'weighted_rating': 7.2008462540630775},
#  {'title': 'Furious 7', 'weighted_rating': 7.196988516541589},
#  {'title': 'The Terminator', 'weighted_rating': 7.196159783770403},
#  {'title': 'Shrek', 'weighted_rating': 7.194891377220368},
#  {'title': 'Children of Men', 'weighted_rating': 7.194497297254754},
#  {'title': 'The Fifth Element', 'weighted_rating': 7.191751010568497},
#  {'title': 'Casino Royale', 'weighted_rating': 7.191180618591304},
#  {'title': 'Toy Story 2', 'weighted_rating': 7.190235938963882},
#  {'title': 'The Age of Adaline', 'weighted_rating': 7.1901493401650125},
#  {'title': 'Midnight in Paris', 'weighted_rating': 7.1901493401650125},
#  {'title': 'The Great Gatsby', 'weighted_rating': 7.189511669202791},
#  {'title': 'The Bourne Identity', 'weighted_rating': 7.185720982382362},
#  {'title': 'District 9', 'weighted_rating': 7.181320920597605},
#  {'title': 'The Curious Case of Benjamin Button',
#   'weighted_rating': 7.179238993818753},
#  {'title': 'E.T. the Extra-Terrestrial', 'weighted_rating': 7.178695174430774},
#  {'title': 'The Bourne Ultimatum', 'weighted_rating': 7.168916666783966},
#  {'title': 'Avatar', 'weighted_rating': 7.168052537972763},
#  {'title': 'Mad Max: Fury Road', 'weighted_rating': 7.161322965353004},
#  {'title': 'The Big Short', 'weighted_rating': 7.1606307045232676},
#  {'title': 'Blood Diamond', 'weighted_rating': 7.149601333662119},
#  {'title': 'Pitch Perfect', 'weighted_rating': 7.148349668058876},
#  {'title': 'The Hangover', 'weighted_rating': 7.145613467544715},
#  {'title': 'Life of Pi', 'weighted_rating': 7.142935240313243},
#  {'title': 'Predator', 'weighted_rating': 7.1424092521462414},
#  {'title': 'Southpaw', 'weighted_rating': 7.141360099832983},
#  {'title': 'American Psycho', 'weighted_rating': 7.141319468775672},
#  {'title': 'The Butterfly Effect', 'weighted_rating': 7.1410752446869825},
#  {'title': 'Zodiac', 'weighted_rating': 7.139552424998118},
#  {'title': 'Creed', 'weighted_rating': 7.134935720650006},
#  {'title': 'The Last Samurai', 'weighted_rating': 7.134051463515222},
#  {'title': 'Lost in Translation', 'weighted_rating': 7.134051463515222},
#  {'title': 'Taken', 'weighted_rating': 7.129807606064976},
#  {'title': "Ocean's Eleven", 'weighted_rating': 7.122490435458736},
#  {'title': 'Zombieland', 'weighted_rating': 7.119138841564794},
#  {'title': '(500) Days of Summer', 'weighted_rating': 7.108124100431793},
#  {'title': 'The Bourne Supremacy', 'weighted_rating': 7.106567683211335},
#  {'title': 'Sin City', 'weighted_rating': 7.103803535542838},
#  {'title': 'Bridge of Spies', 'weighted_rating': 7.101453777963481},
#  {'title': 'The Girl with the Dragon Tattoo',
#   'weighted_rating': 7.098016977316668},
#  {'title': 'Sicario', 'weighted_rating': 7.097585495930739},
#  {'title': 'Saw', 'weighted_rating': 7.091678533683307},
#  {'title': 'Scott Pilgrim vs. the World',
#   'weighted_rating': 7.090093768007198},
#  {'title': 'Corpse Bride', 'weighted_rating': 7.083262172834566},
#  {'title': 'The Hurt Locker', 'weighted_rating': 7.081548427002972},
#  {'title': 'Captain America: Civil War', 'weighted_rating': 7.072258930533707},
#  {'title': 'Despicable Me', 'weighted_rating': 7.069713786480657},
#  {'title': 'X-Men: First Class', 'weighted_rating': 7.0641176929492175},
#  {'title': 'The Hobbit: The Battle of the Five Armies',
#   'weighted_rating': 7.0618282816876405},
#  {'title': 'Kick-Ass', 'weighted_rating': 7.061151206756907},
#  {'title': 'Wreck-It Ralph', 'weighted_rating': 7.060696544205689},
#  {'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'weighted_rating': 7.057699807518429},
#  {'title': 'Ice Age', 'weighted_rating': 7.055776193750699},
#  {'title': 'Argo', 'weighted_rating': 7.052128280284284},
#  {'title': 'The Social Network', 'weighted_rating': 7.051835341317882},
#  {'title': 'Mission: Impossible - Rogue Nation',
#   'weighted_rating': 7.050246470821691},
#  {'title': 'The Equalizer', 'weighted_rating': 7.047443396604568},
#  {'title': 'Back to the Future Part III',
#   'weighted_rating': 7.046844448313298},
#  {'title': 'Indiana Jones and the Temple of Doom',
#   'weighted_rating': 7.045475112327951},
#  {'title': 'Source Code', 'weighted_rating': 7.044489737269744},
#  {'title': 'Minority Report', 'weighted_rating': 7.043353664512354},
#  {'title': 'Fast Five', 'weighted_rating': 7.041101799150625},
#  {'title': 'Home Alone', 'weighted_rating': 7.040769385261907},
#  {'title': 'The Man from U.N.C.L.E.', 'weighted_rating': 7.038618641586911},
#  {'title': 'Nerve', 'weighted_rating': 7.037335854577234},
#  {'title': 'Rise of the Guardians', 'weighted_rating': 7.033019820733894},
#  {'title': 'Gangs of New York', 'weighted_rating': 7.032805392670935},
#  {'title': 'Les Misérables', 'weighted_rating': 7.032336055740311},
#  {'title': 'The Intern', 'weighted_rating': 7.032281479240666},
#  {'title': 'The Hobbit: An Unexpected Journey',
#   'weighted_rating': 6.993287658492781},
#  {'title': 'Ant-Man', 'weighted_rating': 6.991185703499137},
#  {'title': 'Sherlock Holmes', 'weighted_rating': 6.99105356555254},
#  {'title': 'The Maze Runner', 'weighted_rating': 6.990563394164248},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'weighted_rating': 6.990396890899404},
#  {'title': '300', 'weighted_rating': 6.990047068772528},
#  {'title': 'Despicable Me 2', 'weighted_rating': 6.989493735350362},
#  {'title': 'Maleficent', 'weighted_rating': 6.989259872109077},
#  {'title': 'Rise of the Planet of the Apes',
#   'weighted_rating': 6.989001153342991},
#  {'title': 'Sherlock Holmes: A Game of Shadows',
#   'weighted_rating': 6.988115389191485},
#  {'title': 'Monsters University', 'weighted_rating': 6.987322550292139},
#  {'title': '22 Jump Street', 'weighted_rating': 6.986808805577953},
#  {'title': 'The Secret Life of Walter Mitty',
#   'weighted_rating': 6.986345482877274},
#  {'title': 'The Devil Wears Prada', 'weighted_rating': 6.986190267515373},
#  {'title': 'Watchmen', 'weighted_rating': 6.985367517074835},
#  {'title': '127 Hours', 'weighted_rating': 6.984692587050612},
#  {'title': 'Crazy, Stupid, Love.', 'weighted_rating': 6.984109808447642},
#  {'title': 'Juno', 'weighted_rating': 6.983335227779672},
#  {'title': 'Hugo', 'weighted_rating': 6.982903888497697},
#  {'title': 'Superbad', 'weighted_rating': 6.982725912524815},
#  {'title': 'Batman', 'weighted_rating': 6.982708350418802},
#  {'title': 'The Impossible', 'weighted_rating': 6.982390571488258},
#  {'title': 'The Conjuring 2', 'weighted_rating': 6.982037211249864},
#  {'title': 'The Terminal', 'weighted_rating': 6.981850318505957},
#  {'title': 'Love Actually', 'weighted_rating': 6.981649601847045},
#  {'title': 'Snow White and the Seven Dwarfs',
#   'weighted_rating': 6.930862310491348},
#  {'title': 'Unbreakable', 'weighted_rating': 6.930601346022549},
#  {'title': 'Die Hard: With a Vengeance', 'weighted_rating': 6.929660827243042},
#  {'title': 'The Simpsons Movie', 'weighted_rating': 6.928229264305708},
#  {'title': 'Mean Girls', 'weighted_rating': 6.927849108764846},
#  {'title': 'Troy', 'weighted_rating': 6.925189832054582},
#  {'title': 'Kung Fu Panda', 'weighted_rating': 6.9232386992590875},
#  {'title': 'Men in Black', 'weighted_rating': 6.918528051626733},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'weighted_rating': 6.918270815014473},
#  {'title': 'Divergent', 'weighted_rating': 6.917812737854575},
#  {'title': 'Silver Linings Playbook', 'weighted_rating': 6.9175988897160865},
#  {'title': 'I Am Legend', 'weighted_rating': 6.9173069512938605},
#  {'title': 'Skyfall', 'weighted_rating': 6.912264650288882},
#  {'title': 'The Hunger Games', 'weighted_rating': 6.9102544613568755},
#  {'title': 'Pitch Perfect 2', 'weighted_rating': 6.879305455718752},
#  {'title': 'A.I. Artificial Intelligence',
#   'weighted_rating': 6.8785981885132035},
#  {'title': 'Non-Stop', 'weighted_rating': 6.872970907336775},
#  {'title': "A Bug's Life", 'weighted_rating': 6.87235421207508},
#  {'title': 'The Croods', 'weighted_rating': 6.870714998321549},
#  {'title': '10 Cloverfield Lane', 'weighted_rating': 6.8695819556677815},
#  {'title': 'Hotel Transylvania', 'weighted_rating': 6.86803372397778},
#  {'title': 'American Hustle', 'weighted_rating': 6.864504183469181},
#  {'title': "We're the Millers", 'weighted_rating': 6.862291645993626},
#  {'title': 'X2', 'weighted_rating': 6.856067609813587},
#  {'title': 'Mission: Impossible - Ghost Protocol',
#   'weighted_rating': 6.851570930381339},
#  {'title': 'X-Men', 'weighted_rating': 6.850484842451685},
#  {'title': 'Thor: The Dark World', 'weighted_rating': 6.845446618419591},
#  {'title': 'Spider-Man', 'weighted_rating': 6.842183705533651},
#  {'title': 'Kung Fu Panda 2', 'weighted_rating': 6.830025745989602},
#  {'title': 'Megamind', 'weighted_rating': 6.828710396626486},
#  {'title': 'Iron Man 3', 'weighted_rating': 6.828150739721143},
#  {'title': 'The Adventures of Tintin', 'weighted_rating': 6.823990289246483},
#  {'title': 'Easy A', 'weighted_rating': 6.819426868364721},
#  {'title': 'Cinderella', 'weighted_rating': 6.814777260917229},
#  {'title': 'Focus', 'weighted_rating': 6.810375247440357},
#  {'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'weighted_rating': 6.8082257541047895},
#  {'title': 'Mission: Impossible', 'weighted_rating': 6.808177324447964},
#  {'title': 'Snowpiercer', 'weighted_rating': 6.803036342572614},
#  {'title': 'The Jungle Book', 'weighted_rating': 6.802208636455212},
#  {'title': 'Shrek 2', 'weighted_rating': 6.800175645178132},
#  {'title': 'Now You See Me 2', 'weighted_rating': 6.795298563860081},
#  {'title': 'Independence Day', 'weighted_rating': 6.7948312674344375},
#  {'title': 'In Time', 'weighted_rating': 6.791998274895866},
#  {'title': 'The Matrix Reloaded', 'weighted_rating': 6.791545373175244},
#  {'title': 'Charlie and the Chocolate Factory',
#   'weighted_rating': 6.7885119606560735},
#  {'title': 'I, Robot', 'weighted_rating': 6.785855690216951},
#  {'title': '21 Jump Street', 'weighted_rating': 6.781775207003541},
#  {'title': 'Die Hard 2', 'weighted_rating': 6.778697443736005},
#  {'title': 'Spider-Man 2', 'weighted_rating': 6.778495914194197},
#  {'title': 'The Italian Job', 'weighted_rating': 6.777603591283263},
#  {'title': 'Chronicle', 'weighted_rating': 6.776850515155492},
#  {'title': 'Dredd', 'weighted_rating': 6.776616486843038},
#  {'title': 'The Purge: Anarchy', 'weighted_rating': 6.775964490530464},
#  {'title': 'Brave', 'weighted_rating': 6.774619213798768},
#  {'title': 'Pacific Rim', 'weighted_rating': 6.77289785505816},
#  {'title': 'Rango', 'weighted_rating': 6.771576010152654},
#  {'title': '50 First Dates', 'weighted_rating': 6.769226488281111},
#  {'title': 'The Book of Eli', 'weighted_rating': 6.766731894335333},
#  {'title': 'World War Z', 'weighted_rating': 6.765350310051868},
#  {'title': "Ender's Game", 'weighted_rating': 6.761135783524348},
#  {'title': 'King Kong', 'weighted_rating': 6.759823665729686},
#  {'title': 'Super 8', 'weighted_rating': 6.756158499997129},
#  {'title': 'The Mask', 'weighted_rating': 6.754818052590881},
#  {'title': 'Underworld', 'weighted_rating': 6.753394569209207},
#  {'title': 'Star Trek Beyond', 'weighted_rating': 6.751445110268639},
#  {'title': 'Real Steel', 'weighted_rating': 6.747299958919242},
#  {'title': 'RED', 'weighted_rating': 6.743622532258897},
#  {'title': 'Cloud Atlas', 'weighted_rating': 6.738581993995874},
#  {'title': 'Chappie', 'weighted_rating': 6.736178216857345},
#  {'title': 'Madagascar', 'weighted_rating': 6.7314827863592495},
#  {'title': 'Dumb and Dumber', 'weighted_rating': 6.730207100634969},
#  {'title': 'Blade', 'weighted_rating': 6.727378248086696},
#  {'title': 'The Fast and the Furious', 'weighted_rating': 6.726714213483164},
#  {'title': "Ocean's Thirteen", 'weighted_rating': 6.7218084468358095},
#  {'title': 'Mission: Impossible III', 'weighted_rating': 6.7201447687481215},
#  {'title': 'Cars', 'weighted_rating': 6.716759585311218},
#  {'title': 'The Hunger Games: Mockingjay - Part 2',
#   'weighted_rating': 6.714613859214024},
#  {'title': 'Angels & Demons', 'weighted_rating': 6.7145404380419755},
#  {'title': 'Transformers', 'weighted_rating': 6.713522001545954},
#  {'title': 'Rio', 'weighted_rating': 6.712558119540439},
#  {'title': 'Hellboy', 'weighted_rating': 6.709471805357024},
#  {'title': 'Friends with Benefits', 'weighted_rating': 6.708855016412556},
#  {'title': 'The Cabin in the Woods', 'weighted_rating': 6.707531022062645},
#  {'title': 'Ice Age: Dawn of the Dinosaurs',
#   'weighted_rating': 6.707127009755132},
#  {'title': 'Horrible Bosses', 'weighted_rating': 6.706825031318398},
#  {'title': 'Looper', 'weighted_rating': 6.70210970007769},
#  {'title': 'Flight', 'weighted_rating': 6.700114669179417},
#  {'title': 'The Hunger Games: Mockingjay - Part 1',
#   'weighted_rating': 6.689907271756808},
#  {'title': 'The Da Vinci Code', 'weighted_rating': 6.6873828227121646},
#  {'title': 'Thor', 'weighted_rating': 6.679791440549026},
#  {'title': 'Ice Age: The Meltdown', 'weighted_rating': 6.677719074182097},
#  {'title': 'White House Down', 'weighted_rating': 6.67752660853964},
#  {'title': 'Mr. & Mrs. Smith', 'weighted_rating': 6.677201093785181},
#  {'title': 'Iron Man 2', 'weighted_rating': 6.676815587389521},
#  {'title': 'Captain America: The First Avenger',
#   'weighted_rating': 6.675103848322837},
#  {'title': 'National Treasure', 'weighted_rating': 6.674946268698262},
#  {'title': 'Resident Evil', 'weighted_rating': 6.665155437282301},
#  {'title': 'Live Free or Die Hard', 'weighted_rating': 6.6635350954544315},
#  {'title': "Ocean's Twelve", 'weighted_rating': 6.661207281922001},
#  {'title': 'Cloverfield', 'weighted_rating': 6.653095254533119},
#  {'title': 'American Pie', 'weighted_rating': 6.650340492910152},
#  {'title': 'The Amazing Spider-Man 2', 'weighted_rating': 6.641451080846833},
#  {'title': 'Armageddon', 'weighted_rating': 6.639562941831251},
#  {'title': 'Wanted', 'weighted_rating': 6.6370391475558215},
#  {'title': 'Warm Bodies', 'weighted_rating': 6.630493437976067},
#  {'title': 'Bruce Almighty', 'weighted_rating': 6.613386057621585},
#  {'title': 'Maze Runner: The Scorch Trials',
#   'weighted_rating': 6.612161309832678},
#  {'title': 'The Matrix Revolutions', 'weighted_rating': 6.609753512866353},
#  {'title': 'Man of Steel', 'weighted_rating': 6.603833866090191},
#  {'title': 'The Amazing Spider-Man', 'weighted_rating': 6.60103600658655},
#  {'title': 'Kick-Ass 2', 'weighted_rating': 6.600031442961731},
#  {'title': 'Warcraft', 'weighted_rating': 6.596816611603286},
#  {'title': 'Elysium', 'weighted_rating': 6.59612076664413},
#  {'title': 'This Is the End', 'weighted_rating': 6.5903816014408285},
#  {'title': 'Home Alone 2: Lost in New York',
#   'weighted_rating': 6.587912253481299},
#  {'title': 'Jurassic World', 'weighted_rating': 6.58106050568433},
#  {'title': 'Star Wars: Episode II - Attack of the Clones',
#   'weighted_rating': 6.5775191640175175},
#  {'title': 'The 40 Year Old Virgin', 'weighted_rating': 6.567061216802149},
#  {'title': '2 Fast 2 Furious', 'weighted_rating': 6.562789089046073},
#  {'title': 'Riddick', 'weighted_rating': 6.562133457398598},
#  {'title': 'Minions', 'weighted_rating': 6.561482780585973},
#  {'title': 'TRON: Legacy', 'weighted_rating': 6.56047094368674},
#  {'title': 'Alice in Wonderland', 'weighted_rating': 6.559639654176472},
#  {'title': 'Night at the Museum', 'weighted_rating': 6.559307236381528},
#  {'title': 'X-Men: Apocalypse', 'weighted_rating': 6.557790001202509},
#  {'title': 'Salt', 'weighted_rating': 6.556790897361687},
#  {'title': 'Oblivion', 'weighted_rating': 6.555912227929582},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'weighted_rating': 6.552512043776927},
#  {'title': 'Jack Reacher', 'weighted_rating': 6.5520154937324735},
#  {'title': 'Prince of Persia: The Sands of Time',
#   'weighted_rating': 6.537557812457942},
#  {'title': 'War of the Worlds', 'weighted_rating': 6.537152132940999},
#  {'title': 'Dracula Untold', 'weighted_rating': 6.531808613778619},
#  {'title': 'The Day After Tomorrow', 'weighted_rating': 6.5315733107714955},
#  {'title': 'Night at the Museum: Secret of the Tomb',
#   'weighted_rating': 6.5300232378944365},
#  {'title': 'Underworld: Awakening', 'weighted_rating': 6.528744928626022},
#  {'title': 'X-Men: The Last Stand', 'weighted_rating': 6.527252812374191},
#  {'title': 'Ted 2', 'weighted_rating': 6.526100277557942},
#  {'title': 'The Lost World: Jurassic Park',
#   'weighted_rating': 6.524290871107351},
#  {'title': 'Paper Towns', 'weighted_rating': 6.520227719946956},
#  {'title': 'Ice Age: Continental Drift', 'weighted_rating': 6.51098965366436},
#  {'title': 'Neighbors', 'weighted_rating': 6.50818819130108},
#  {'title': 'The Wolverine', 'weighted_rating': 6.506885924209481},
#  {'title': 'John Carter', 'weighted_rating': 6.500395652606434},
#  {'title': 'Tomorrowland', 'weighted_rating': 6.4994380782784855},
#  {'title': 'Star Wars: Episode I - The Phantom Menace',
#   'weighted_rating': 6.494381177259463},
#  {'title': 'Spectre', 'weighted_rating': 6.493332868137767},
#  {'title': 'Taken 3', 'weighted_rating': 6.492860472931788},
#  {'title': 'Hancock', 'weighted_rating': 6.492263144119626},
#  {'title': 'Olympus Has Fallen', 'weighted_rating': 6.491050282999488},
#  {'title': 'Ted', 'weighted_rating': 6.486499331928839},
#  {'title': 'The Interview', 'weighted_rating': 6.482997232012297},
#  {'title': 'Prometheus', 'weighted_rating': 6.476174799648435},
#  {'title': '300: Rise of an Empire', 'weighted_rating': 6.474587461370291},
#  {'title': 'Shrek Forever After', 'weighted_rating': 6.466205228284546},
#  {'title': 'The Twilight Saga: Breaking Dawn - Part 2',
#   'weighted_rating': 6.461280624376676},
#  {'title': 'Percy Jackson & the Olympians: The Lightning Thief',
#   'weighted_rating': 6.460026955069051},
#  {'title': 'Lucy', 'weighted_rating': 6.457955488814439},
#  {'title': 'The Hangover Part II', 'weighted_rating': 6.451494914097561},
#  {'title': 'Click', 'weighted_rating': 6.4490583740583745},
#  {'title': 'Insurgent', 'weighted_rating': 6.447501099955488},
#  {'title': 'Taken 2', 'weighted_rating': 6.4452425760298855},
#  {'title': 'X-Men Origins: Wolverine', 'weighted_rating': 6.439391018515161},
#  {'title': 'The Mummy Returns', 'weighted_rating': 6.437733096105166},
#  {'title': 'The Expendables 2', 'weighted_rating': 6.435106398675172},
#  {'title': 'Men in Black 3', 'weighted_rating': 6.433843647287233},
#  {'title': 'Quantum of Solace', 'weighted_rating': 6.430292653930078},
#  {'title': 'Shrek the Third', 'weighted_rating': 6.4300767014594635},
#  {'title': 'The Incredible Hulk', 'weighted_rating': 6.426486342735263},
#  {'title': 'Mission: Impossible II', 'weighted_rating': 6.418852945488459},
#  {'title': 'The Purge', 'weighted_rating': 6.41495587237196},
#  {'title': 'Night at the Museum: Battle of the Smithsonian',
#   'weighted_rating': 6.4129962025221126},
#  {'title': 'Allegiant', 'weighted_rating': 6.40938581323317},
#  {'title': 'Transformers: Dark of the Moon',
#   'weighted_rating': 6.408819195290952},
#  {'title': 'The Bourne Legacy', 'weighted_rating': 6.394343951059771},
#  {'title': 'Terminator 3: Rise of the Machines',
#   'weighted_rating': 6.390834313027511},
#  {'title': 'Transcendence', 'weighted_rating': 6.372784568124966},
#  {'title': 'The Expendables', 'weighted_rating': 6.371582514878628},
#  {'title': 'The Lone Ranger', 'weighted_rating': 6.370961520674733},
#  {'title': 'San Andreas', 'weighted_rating': 6.368335497230305},
#  {'title': 'Jason Bourne', 'weighted_rating': 6.367580928814599},
#  {'title': 'Men in Black II', 'weighted_rating': 6.357476725201465},
#  {'title': 'Transformers: Revenge of the Fallen',
#   'weighted_rating': 6.355752699519278},
#  {'title': 'Terminator Salvation', 'weighted_rating': 6.354318997044622},
#  {'title': 'Cars 2', 'weighted_rating': 6.352267328069364},
#  {'title': 'The Twilight Saga: Eclipse',
#   'weighted_rating': 6.3165115074377285},
#  {'title': 'Jurassic Park III', 'weighted_rating': 6.293014183451943},
#  {'title': 'Teenage Mutant Ninja Turtles',
#   'weighted_rating': 6.27784009786513},
#  {'title': 'Lara Croft: Tomb Raider', 'weighted_rating': 6.276093621945151},
#  {'title': 'The Secret Life of Pets', 'weighted_rating': 6.268690614649411},
#  {'title': 'Exodus: Gods and Kings', 'weighted_rating': 6.266523310604813},
#  {'title': 'The 5th Wave', 'weighted_rating': 6.262295219614034},
#  {'title': 'Spider-Man 3', 'weighted_rating': 6.260927846832103},
#  {'title': 'G.I. Joe: The Rise of Cobra',
#   'weighted_rating': 6.259332631798689},
#  {'title': 'Dark Shadows', 'weighted_rating': 6.2583608440476475},
#  {'title': 'RoboCop', 'weighted_rating': 6.255422383955539},
#  {'title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'weighted_rating': 6.2358120030202},
#  {'title': 'Transformers: Age of Extinction',
#   'weighted_rating': 6.233382197650249},
#  {'title': 'Snow White and the Huntsman', 'weighted_rating': 6.23137110279391},
#  {'title': 'Clash of the Titans', 'weighted_rating': 6.215446218472205},
#  {'title': 'Sausage Party', 'weighted_rating': 6.214691329086383},
#  {'title': 'Noah', 'weighted_rating': 6.198254162421864},
#  {'title': 'Twilight', 'weighted_rating': 6.195978763175118},
#  {'title': 'Terminator Genisys', 'weighted_rating': 6.19091083736566},
#  {'title': 'The Twilight Saga: New Moon',
#   'weighted_rating': 6.186217418558799},
#  {'title': 'Battleship', 'weighted_rating': 6.180489761635396},
#  {'title': 'Pixels', 'weighted_rating': 6.175844034997411},
#  {'title': 'Hansel & Gretel: Witch Hunters',
#   'weighted_rating': 6.157298564991478},
#  {'title': 'Oz: The Great and Powerful', 'weighted_rating': 6.13251019556809},
#  {'title': 'The Legend of Tarzan', 'weighted_rating': 6.130111454851404},
#  {'title': 'Suicide Squad', 'weighted_rating': 6.110211235950231},
#  {'title': 'Jack the Giant Slayer', 'weighted_rating': 6.1062500527201635},
#  {'title': 'Ghostbusters', 'weighted_rating': 6.068075503438784},
#  {'title': 'Fantastic 4: Rise of the Silver Surfer',
#   'weighted_rating': 6.049005676895636},
#  {'title': 'G.I. Joe: Retaliation', 'weighted_rating': 5.99082282639465},
#  {'title': '2012', 'weighted_rating': 5.971692487300522},
#  {'title': 'Batman v Superman: Dawn of Justice',
#   'weighted_rating': 5.9625856932380055},
#  {'title': 'Jupiter Ascending', 'weighted_rating': 5.90360536077799},
#  {'title': 'Green Lantern', 'weighted_rating': 5.891817573840046},
#  {'title': 'Fifty Shades of Grey', 'weighted_rating': 5.836455842802556},
#  {'title': 'After Earth', 'weighted_rating': 5.825729391791995},
#  {'title': 'A Good Day to Die Hard', 'weighted_rating': 5.807924322670919},
#  {'title': 'Independence Day: Resurgence',
#   'weighted_rating': 5.77601231900211},
#  {'title': 'Fantastic Four', 'weighted_rating': 5.544642827200403}]
